# %%
import pandas as pd

# %% [markdown]
# Creates a **dataframe** called pokemon

# %% [markdown]
# **usecols**: provide a List to specify which columns you want
# __squeeze__: by default you'll get a dataframe. We want a _Series_. Squeeze specifies a __*Series*__.

# %%
pokemon = pd.read_csv("data/pokemon.csv", usecols=["Pokemon"], squeeze=True)
pokemon
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
# 5       Charizard
# 6        Squirtle
# 7       Wartortle
# 8       Blastoise
# 9        Caterpie
# 10        Metapod
# 11     Butterfree
# 12         Weedle
# 13         Kakuna
# 14       Beedrill
# 15         Pidgey
# 16      Pidgeotto
# 17        Pidgeot
# 18        Rattata
# 19       Raticate
# 20        Spearow
# 21         Fearow
# 22          Ekans
# 23          Arbok
# 24        Pikachu
# 25         Raichu
# 26      Sandshrew
# 27      Sandslash
# 28        Nidoran
# 29       Nidorina
#           ...
# 691     Clauncher
# 692     Clawitzer
# 693    Helioptile
# 694     Heliolisk
# 695        Tyrunt
# 696     Tyrantrum
# 697        Amaura
# 698       Aurorus
# 699       Sylveon
# 700      Hawlucha
# 701       Dedenne
# 702       Carbink
# 703         Goomy
# 704       Sliggoo
# 705        Goodra
# 706        Klefki
# 707      Phantump
# 708     Trevenant
# 709     Pumpkaboo
# ...

# %%
google = pd.read_csv("data/google_stock_price.csv", squeeze=True)
google
# Out:
# 0        50.12
# 1        54.10
# 2        54.65
# 3        52.38
# 4        52.95
# 5        53.90
# 6        53.02
# 7        50.95
# 8        51.13
# 9        50.07
# 10       50.70
# 11       49.95
# 12       50.74
# 13       51.10
# 14       51.10
# 15       52.61
# 16       53.70
# 17       55.69
# 18       55.94
# 19       56.93
# 20       58.69
# 21       59.62
# 22       58.86
# 23       59.13
# 24       60.35
# 25       59.86
# 26       59.07
# 27       63.37
# 28       65.47
# 29       64.74
#          ...
# 2982    675.22
# 2983    668.26
# 2984    680.04
# 2985    684.11
# 2986    692.10
# 2987    699.21
# 2988    694.49
# 2989    697.77
# 2990    695.36
# 2991    705.63
# 2992    715.09
# 2993    720.64
# 2994    716.98
# 2995    720.95
# 2996    719.85
# 2997    733.78
# 2998    736.96
# 2999    741.19
# 3000    738.63
# 3001    742.74
# 3002    739.77
# 3003    738.42
# 3004    741.77
# 3005    745.91
# 3006    768.79
# 3007    772.88
# 3008    771.07
# ...

# %%
google.head(10)
# Out:
# 0    50.12
# 1    54.10
# 2    54.65
# 3    52.38
# 4    52.95
# 5    53.90
# 6    53.02
# 7    50.95
# 8    51.13
# 9    50.07
# Name: Stock Price, dtype: float64

# %%
google.tail(10)
# Out:
# 3002    739.77
# 3003    738.42
# 3004    741.77
# 3005    745.91
# 3006    768.79
# 3007    772.88
# 3008    771.07
# 3009    773.18
# 3010    771.61
# 3011    782.22
# Name: Stock Price, dtype: float64

# %%
bottom_five = google.sort_values(ascending=True).head(5)
bottom_five
# Out:
# 11    49.95
# 9     50.07
# 0     50.12
# 10    50.70
# 12    50.74
# Name: Stock Price, dtype: float64

# %%
bottom_five.sum()
# Out:
# 251.58000000000004

# %%
print(len(bottom_five),len(google))
# Out:
# 5 3012

# %%
type(bottom_five)
# Out:
# pandas.core.series.Series

# %% [markdown]
# `dir` gives list of methods and attributes of the object

# %%
dir(bottom_five)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
# ...

# %%
sorted(pokemon)
# Out:
# ['Abomasnow',
#  'Abra',
#  'Absol',
#  'Accelgor',
#  'Aegislash',
#  'Aerodactyl',
#  'Aggron',
#  'Aipom',
#  'Alakazam',
#  'Alomomola',
#  'Altaria',
#  'Amaura',
#  'Ambipom',
#  'Amoonguss',
#  'Ampharos',
#  'Anorith',
#  'Arbok',
#  'Arcanine',
#  'Arceus',
#  'Archen',
#  'Archeops',
#  'Ariados',
#  'Armaldo',
#  'Aromatisse',
#  'Aron',
#  'Articuno',
#  'Audino',
#  'Aurorus',
#  'Avalugg',
#  'Axew',
#  'Azelf',
#  'Azumarill',
#  'Azurill',
#  'Bagon',
#  'Baltoy',
#  'Banette',
#  'Barbaracle',
#  'Barboach',
#  'Basculin',
#  'Bastiodon',
#  'Bayleef',
#  'Beartic',
#  'Beautifly',
#  'Beedrill',
#  'Beheeyem',
#  'Beldum',
#  'Bellossom',
#  'Bellsprout',
#  'Bergmite',
#  'Bibarel',
#  'Bidoof',
#  'Binacle',
#  'Bisharp',
#  'Blastoise',
#  'Blaziken',
#  'Blissey',
#  'Blitzle',
#  'Boldore',
#  'Bonsly',
#  'Bouffalant',
#  'Braixen',
#  'Braviary',
#  'Breloom',
#  'Bronzong',
#  'Bronzor',
#  'Budew',
#  'Buizel',
#  'Bulbasaur',
#  'Buneary',
#  'Bunnelby',
# ...

# %%
sorted(google, reverse=True)
# Out:
# [782.22,
#  776.6,
#  773.18,
#  772.88,
#  771.61,
#  771.07,
#  771.0,
#  768.79,
#  767.04,
#  766.81,
#  766.61,
#  764.65,
#  763.25,
#  762.51,
#  762.38,
#  762.37,
#  759.14,
#  759.0,
#  758.88,
#  758.09,
#  756.6,
#  755.98,
#  753.93,
#  753.2,
#  752.67,
#  752.54,
#  752.0,
#  751.72,
#  751.61,
#  750.53,
#  750.31,
#  750.26,
#  750.0,
#  749.91,
#  749.46,
#  749.43,
#  748.4,
#  748.28,
#  748.15,
#  747.77,
#  747.77,
#  745.91,
#  745.69,
#  745.29,
#  744.95,
#  744.77,
#  743.62,
#  743.4,
#  743.09,
#  742.95,
#  742.74,
#  742.6,
#  742.58,
#  742.09,
#  741.84,
#  741.77,
#  741.19,
#  740.75,
#  740.28,
#  740.0,
#  739.77,
#  739.31,
#  739.15,
#  738.87,
#  738.63,
#  738.42,
#  738.41,
#  738.06,
#  737.8,
#  737.78,
#  737.6,
#  736.96,
#  736.1,
#  736.09,
#  735.72,
#  735.4,
#  735.3,
#  734.15,
#  733.78,
#  733.76,
#  733.53,
#  732.66,
#  731.25,
#  731.23,
#  730.96,
#  730.49,
#  730.4,
#  728.96,
#  728.58,
#  728.33,
#  728.32,
#  728.28,
# ...

# %%
list(google)
# Out:
# [50.12,
#  54.1,
#  54.65,
#  52.38,
#  52.95,
#  53.9,
#  53.02,
#  50.95,
#  51.13,
#  50.07,
#  50.7,
#  49.95,
#  50.74,
#  51.1,
#  51.1,
#  52.61,
#  53.7,
#  55.69,
#  55.94,
#  56.93,
#  58.69,
#  59.62,
#  58.86,
#  59.13,
#  60.35,
#  59.86,
#  59.07,
#  63.37,
#  65.47,
#  64.74,
#  66.22,
#  67.46,
#  69.12,
#  68.47,
#  69.36,
#  68.8,
#  67.56,
#  68.63,
#  70.38,
#  70.93,
#  71.98,
#  74.51,
#  73.9,
#  70.17,
#  74.62,
#  86.13,
#  93.61,
#  90.81,
#  92.89,
#  96.55,
#  95.22,
#  97.92,
#  97.34,
#  95.74,
#  92.26,
#  84.59,
#  86.19,
#  84.27,
#  83.85,
#  91.42,
#  90.91,
#  92.34,
#  86.19,
#  86.16,
#  83.69,
#  84.62,
#  82.47,
#  83.68,
#  87.29,
#  89.61,
#  90.43,
#  90.9,
#  89.89,
#  89.61,
#  90.11,
#  88.06,
#  85.63,
#  84.91,
#  86.63,
#  85.74,
#  85.14,
#  89.26,
#  89.8,
#  88.15,
#  89.95,
#  92.42,
#  91.78,
#  93.06,
#  93.86,
#  95.86,
#  96.28,
#  96.35,
#  98.7,
#  96.3,
#  101.25,
#  97.15,
#  96.66,
#  94.18,
#  96.83,
#  97.43,
#  96.67,
# ...

# %%
google_dict = dict(google)

# %%
print(min(google), max(pokemon))
# Out:
# 49.95 Zygarde

# %%
google_dict[5]
# Out:
# 53.9

# %%
google_dict
# Out:
# {0: 50.12,
#  1: 54.1,
#  2: 54.65,
#  3: 52.38,
#  4: 52.95,
#  5: 53.9,
#  6: 53.02,
#  7: 50.95,
#  8: 51.13,
#  9: 50.07,
#  10: 50.7,
#  11: 49.95,
#  12: 50.74,
#  13: 51.1,
#  14: 51.1,
#  15: 52.61,
#  16: 53.7,
#  17: 55.69,
#  18: 55.94,
#  19: 56.93,
#  20: 58.69,
#  21: 59.62,
#  22: 58.86,
#  23: 59.13,
#  24: 60.35,
#  25: 59.86,
#  26: 59.07,
#  27: 63.37,
#  28: 65.47,
#  29: 64.74,
#  30: 66.22,
#  31: 67.46,
#  32: 69.12,
#  33: 68.47,
#  34: 69.36,
#  35: 68.8,
#  36: 67.56,
#  37: 68.63,
#  38: 70.38,
#  39: 70.93,
#  40: 71.98,
#  41: 74.51,
#  42: 73.9,
#  43: 70.17,
#  44: 74.62,
#  45: 86.13,
#  46: 93.61,
#  47: 90.81,
#  48: 92.89,
#  49: 96.55,
#  50: 95.22,
#  51: 97.92,
#  52: 97.34,
#  53: 95.74,
#  54: 92.26,
#  55: 84.59,
#  56: 86.19,
#  57: 84.27,
#  58: 83.85,
#  59: 91.42,
#  60: 90.91,
#  61: 92.34,
#  62: 86.19,
#  63: 86.16,
#  64: 83.69,
#  65: 84.62,
#  66: 82.47,
#  67: 83.68,
#  68: 87.29,
#  69: 89.61,
#  70: 90.43,
#  71: 90.9,
# ...
